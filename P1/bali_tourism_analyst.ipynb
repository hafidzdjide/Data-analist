# %% [markdown]
# <h3> Setup Code </h3>

# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap # Or cartopy
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# <h3> Load Data </h3>

# %%
df_filepath = "dataset_tempat_wisata_bali_cleaned.csv"
df = pd.read_csv(df_filepath, index_col=0)

# %%
df.head
# Out:
# <bound method NDFrame.head of                                             kategori    kabupaten_kota  \
# nama
# Taman Mumbul Sangeh                             Alam  Kabupaten Badung
# Sangeh Monkey Forest                            Alam  Kabupaten Badung
# Objek Wisata Sangeh                             Umum  Kabupaten Badung
# Satria Gatotkaca Park                           Umum  Kabupaten Badung
# Desa Wisata Penarungan                          Umum  Kabupaten Badung
# ...                                              ...               ...
# Pantai Bangsal                              Rekreasi     Kota Denpasar
# Sumber Sari Garden                              Umum     Kota Denpasar
# Pasar Seni Kumbasari                            Umum     Kota Denpasar
# Mangrove Forest Management Center Region I      Alam     Kota Denpasar
# Mangrove Conservation Forest                    Alam     Kota Denpasar
#
#                                             rating       preferensi  \
# nama
# ...

# %%
list(df.columns)
# Out:
# ['kategori',
#  'kabupaten_kota',
#  'rating',
#  'preferensi',
#  'link_lokasi',
#  'latitude',
#  'longitude',
#  'link_gambar']

# %%
df
# Out:
#                                             kategori    kabupaten_kota  \
# nama
# Taman Mumbul Sangeh                             Alam  Kabupaten Badung
# Sangeh Monkey Forest                            Alam  Kabupaten Badung
# Objek Wisata Sangeh                             Umum  Kabupaten Badung
# Satria Gatotkaca Park                           Umum  Kabupaten Badung
# Desa Wisata Penarungan                          Umum  Kabupaten Badung
# ...                                              ...               ...
# Pantai Bangsal                              Rekreasi     Kota Denpasar
# Sumber Sari Garden                              Umum     Kota Denpasar
# Pasar Seni Kumbasari                            Umum     Kota Denpasar
# Mangrove Forest Management Center Region I      Alam     Kota Denpasar
# Mangrove Conservation Forest                    Alam     Kota Denpasar
#
#                                             rating       preferensi  \
# nama
# ...

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# kategori          0
# kabupaten_kota    0
# rating            0
# preferensi        0
# link_lokasi       0
# latitude          0
# longitude         0
# link_gambar       0
# dtype: int64

# %%
m = Basemap(projection='merc', llcrnrlat=-9, urcrnrlat=-7.8, llcrnrlon=114.3, urcrnrlon=115.9, resolution='l')
plt.figure(figsize=(15, 15))
m.bluemarble(alpha=0.9)
x, y = m(df['longitude'].values, df['latitude'].values)
sns.scatterplot(data=df, x=x, y=y, hue='rating', size='rating', alpha=0.9, palette='viridis')
plt.title('Scatter Plot of Tourist Attractions in Bali')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Tourist Attractions in Bali')

# %%
x, y = m(df['longitude'].values, df['latitude'].values)
sns.scatterplot(data=df, x=x, y=y, hue='rating', size='rating', palette='viridis')
plt.title('Scatter Plot of Tourist Attractions in Bali')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Tourist Attractions in Bali')
